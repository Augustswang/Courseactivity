# %% [markdown]
# <a href="https://colab.research.google.com/github/Augustswang/Courseactivity/blob/main/ShuaiWang_Pareto_Chart_of_Top_for_IT_Skills.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.ticker import PercentFormatter

df=pd.read_csv("/content/sample_data/IT_skills.csv")
print(df)

df.index = df['Skill']
df = df.sort_values(by = 'Importance', ascending=False)

df["cumulativePercentage"] = df["Importance"].cumsum()/df["Importance"].sum()*100

df["cumulativePercentage"] = df["cumulativePercentage"].apply(lambda x: round(x,2))
print(df)

fig, ax = plt.subplots()
ax.bar(df.index, df["Importance"], color="C0")

ax.set_xticklabels(df['Skill'], rotation = 45)

ax2=ax.twinx()

ax2.plot(df.index, df["cumulativePercentage"], color="C1", marker = "D", ms = 7, label=df['cumulativePercentage'])
ax2.yaxis.set_major_formatter(PercentFormatter())

ax.tick_params(axis="y", colors="C0")
ax2.tick_params(axis="y", colors="C1")


for index, v in df.iterrows():
  label = round(v['cumulativePercentage'],1)
  plt.annotate(label, xy=(v['Skill'], v['cumulativePercentage']))
plt.show()
# Out:
#                                  Skill  \
# 0        Business Environmental Skills
# 1  Opportunities and Challenges Skills
# 2               Process Centric Skills
# 3             Product Knowledge Skills
# 4            Industry Knowledge Skills
# 5                Competitive Landscape
# 6         Technology Prowess Knowledge
# 7          Organization Agility Skills
# 8  Strategic Project Capability Skills
# 9  Cross-Dimensional Competency Skills
#
#                                          Description  Importance
# 0  IT staff can understand and articulate busines...          21
# 1  IT staff can develop opportunities and challen...           5
# 2           Building a set of process-centric skills          13
# 3  Learn about the products and services the comp...           9
# 4                      Understanding industry trends          12
# 5  Understand the relevant problems and opportuni...           8
# 6  Technology prowess addresses the strategic tec...          17
# ...

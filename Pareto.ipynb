# %% [markdown]
# <a href="https://colab.research.google.com/github/Augustswang/Courseactivity/blob/main/Pareto.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.ticker import PercentFormatter

df=pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Pareto.csv")
print(df)

df.index = df['TrainingArea']
df = df.sort_values(by = 'NumbersOfInterested', ascending=False)

df["cumulativePercentage"] = df["NumbersOfInterested"].cumsum()/df["NumbersOfInterested"].sum()*100

df["cumulativePercentage"] = df["cumulativePercentage"].apply(lambda x: round(x,2))
print(df)

fig, ax = plt.subplots()
ax.bar(df.index, df["NumbersOfInterested"], color="C0")

ax.set_xticklabels(df['TrainingArea'], rotation = 45)

ax2=ax.twinx()

ax2.plot(df.index, df["cumulativePercentage"], color="C1", marker = "D", ms = 7, label=df['cumulativePercentage'])
ax2.yaxis.set_major_formatter(PercentFormatter())

ax.tick_params(axis="y", colors="C0")
ax2.tick_params(axis="y", colors="C1")


for index, v in df.iterrows():
  label = round(v['cumulativePercentage'],1)
  plt.annotate(label, xy=(v['TrainingArea'], v['cumulativePercentage']))
plt.show()
# Out:
#         TrainingArea  NumbersOfInterested
# 0                IBM                   82
# 1                SAP                   48
# 2                AWS                  101
# 3                loT                   55
# 4           Security                   35
# 5                SDN                   64
# 6       Cryptography                   41
# 7              Scrum                   84
# 8  quantum computing                   61
#                         TrainingArea  NumbersOfInterested  \
# TrainingArea
# AWS                              AWS                  101
# Scrum                          Scrum                   84
# IBM                              IBM                   82
# SDN                              SDN                   64
# quantum computing  quantum computing                   61
# loT                              loT                   55
# SAP                              SAP                   48
# Cryptography            Cryptography                   41
# ...
